# %% [markdown]
# <a href="https://colab.research.google.com/github/nomeshmudhiraj8-oss/chatbot/blob/main/calculator_app.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# calculator app on my own
a = int(input("Enter a Number:"))
b = int(input("Enter a Number:"))
c = input("choose an Operation:('+','-','*','/','%')")
match c:
  case '+':
    print("Addition of two numbers:",(a+b))
  case '-':
    print("subtraction of two numbers:",(a-b))
  case '*':
    print("Multiplication of two numbers:",(a*b))
  case '/':
    print("Division of two numbers:",(a/b))
  case '%':
    print("modulo of two numbers:",(a%b))
# Out:
# Enter a Number:50
# Enter a Number:2
# choose an Operation:('+','-','*','/','%')*
# Multiplication of two numbers: 100
