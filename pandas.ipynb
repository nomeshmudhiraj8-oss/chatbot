# %% [markdown]
# <a href="https://colab.research.google.com/github/nomeshmudhiraj8-oss/chatbot/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pandas in python
import pandas as pd
gym = {
    "Client_Names":["Nomesh","Soloman","Bhavesh"],
    "Plan_Details":["1-MONTH","3-MONTHS","1-Year"],
    "Ph_Details":[6666,6689,6612]
}
df=pd.DataFrame(gym)
df
# Out:
#   Client_Names Plan_Details  Ph_Details
# 0       Nomesh      1-MONTH        6666
# 1      Soloman     3-MONTHS        6689
# 2      Bhavesh       1-Year        6612

# %%
import pandas as pd
savings = {
    "monthly_savings":["Nomesh","Charan","Bhavesh"],
    "amount" :[10000,5000,500],
    "interest" :[20,25,20]
}
df=pd.DataFrame(savings)
df
# Out:
#   monthly_savings  amount  interest
# 0          Nomesh   10000        20
# 1          Charan    5000        25
# 2         Bhavesh     500        20

# %%
# im going to print Student Details:
import pandas as pd
students ={
    "student_Names":["Nomesh","Charan","Vishnu"],
    "student_Age":[22,20,23],
    "student_Percentage":[87.5,50.8,90.0]
}
df=pd.DataFrame(students)
df
# Out:
#   student_Names  student_Age  student_Percentage
# 0        Nomesh           22                87.5
# 1        Charan           20                50.8
# 2        Vishnu           23                90.0

# %%
import pandas as pd
workout = {
    "muscle_type":["chest","Shoulders","Biceps","Triceps"],
    "variations":["Bench Press","Dumbell Press","Dumbell Curls","Rope Push Down"],
    "sets":[3,4,3,6]
}
df=pd.DataFrame(workout)
df
# Out:
#   muscle_type      variations  sets
# 0       chest     Bench Press     3
# 1   Shoulders   Dumbell Press     4
# 2      Biceps   Dumbell Curls     3
# 3     Triceps  Rope Push Down     6

# %%
# program for personality Development
import pandas as pd
personality_Development ={
    "skills":["Communication","Self Control","mindset"],
    "knowledge":["Read books","Journaling","Research"],
    "body":["Sleep","Food","Workout"]
}
df=pd.DataFrame(personality_Development)
df
# Out:
#           skills   knowledge     body
# 0  Communication  Read books    Sleep
# 1   Self Control  Journaling     Food
# 2        mindset    Research  Workout
