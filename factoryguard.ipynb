# %% [markdown]
# <a href="https://colab.research.google.com/github/nomeshmudhiraj8-oss/chatbot/blob/main/factoryguard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir factoryguard-ai

# %%
# !mkdir factoryguard-ai/data
# !mkdir factoryguard-ai/data/raw
# !mkdir factoryguard-ai/data/processed
# !mkdir factoryguard-ai/src
# !mkdir factoryguard-ai/notebooks

# %%
# !touch factoryguard-ai/src/data_preprocessing.py
# !touch factoryguard-ai/src/feature_engineering.py

# %%
# !touch factoryguard-ai/README.md
# !touch factoryguard-ai/requirements.txt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !mv factoryguard-ai /content/drive/MyDrive/

# %%
import pandas as pd

# Sample IoT sensor data
data = {
    "timestamp": [
        "2025-01-01 08:00",
        "2025-01-01 09:00",
        "2025-01-01 10:00",
        "2025-01-01 11:00",
        "2025-01-01 12:00",
        "2025-01-01 13:00",
        "2025-01-01 14:00",
        "2025-01-01 15:00"
    ],
    "temperature": [65, 68, 72, 80, 85, 90, 88, 92],
    "vibration": [0.2, 0.25, 0.3, 0.6, 0.9, 1.2, 1.1, 1.3],
    "pressure": [30, 31, 29, 28, 27, 26, 25, 24],
    "failure": [0, 0, 0, 0, 1, 1, 1, 1]
}

df = pd.DataFrame(data)

# Save as CSV in your project folder
df.to_csv(
    "/content/drive/MyDrive/factoryguard-ai/data/raw/sensor_data.csv",
    index=False
)

df
# Out:
#           timestamp  temperature  vibration  pressure  failure
# 0  2025-01-01 08:00           65       0.20        30        0
# 1  2025-01-01 09:00           68       0.25        31        0
# 2  2025-01-01 10:00           72       0.30        29        0
# 3  2025-01-01 11:00           80       0.60        28        0
# 4  2025-01-01 12:00           85       0.90        27        1
# 5  2025-01-01 13:00           90       1.20        26        1
# 6  2025-01-01 14:00           88       1.10        25        1
# 7  2025-01-01 15:00           92       1.30        24        1

# %%
import pandas as pd

path = "/content/drive/MyDrive/factoryguard-ai/data/raw/sensor_data.csv"
df = pd.read_csv(path)

print(df.head())
print(df.shape)
print(df.isnull().sum())
# Out:
#           timestamp  temperature  vibration  pressure  failure
# 0  2025-01-01 08:00           65       0.20        30        0
# 1  2025-01-01 09:00           68       0.25        31        0
# 2  2025-01-01 10:00           72       0.30        29        0
# 3  2025-01-01 11:00           80       0.60        28        0
# 4  2025-01-01 12:00           85       0.90        27        1
# (8, 5)
# timestamp      0
# temperature    0
# vibration      0
# pressure       0
# failure        0
# dtype: int64
