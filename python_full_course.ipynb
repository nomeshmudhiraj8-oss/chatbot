# %%
# basic syntax
print("Welcome Nomesh")
# Out:
# Welcome Nomesh

# %%
# How to take user input
name = input("Enter Your Name:")
age  = int(input("Enter Client Age:"))
print("Welcome:",name)
print("client Age is:",age)
# Out:
# Enter Your Name:Nomesh
# Enter Client Age:21
# Welcome: Nomesh
# client Age is: 21

# %%
# Data Types
name = input("Enter Your Name:")
marks = int(input("Enter Client Marks:"))
percentage =float(input("Enter The Client Percentage:"))
user_found = bool(input("Client Matches"))
print(f"Welcome:{name}")
print(f"Student Marks:{marks}")
print(f"Student Percentage:{percentage}")
print(f"User_Matches:{user_found}")
# Out:
# Enter Your Name:Nomesh
# Enter Client Marks:803
# Enter The Client Percentage:80.3
# Client Matchesyes
# Welcome:Nomesh
# Student Marks:803
# Student Percentage:80.3
# User_Matches:True

# %%
# string slicing
name = input("Enter User Name:")
print(name)
# nomesh
print(name[0:4])
# Out:
# Enter User Name:nomesh
# nomesh
# nome

# %%
# string slicing
name = input("Enter User Name:")
print(name)
# nomesh
print(name[-1::])
# Out:
# Enter User Name:nomesh
# nomesh
# h

# %%
# string slicing
name = input("Enter User Name:")
print(name)
# nomesh
print(name[0::])
# Out:
# Enter User Name:nomesh
# nomesh
# nomesh

# %%
# string slicing
name = input("Enter User Name:")
print(name)
# nomesh
print(name[::-1])
# Out:
# Enter User Name:nomesh
# nomesh
# hsemon

# %%
# lists
names = ["charan","vishnu","prem","Bhavesh","solo"]
print(names[0])
# Out:
# charan

# %%
names = ["sai","solo","nomesh","bhavesh"]
for i in names:
  print(i)
# Out:
# sai
# solo
# nomesh
# bhavesh

# %%
names = ["charan","nomesh","bhavesh"]
marks = [70.2,80.3,70.4]
for i in names:
  print("names:",i)
for j in marks:
  print("marks:",j)
# Out:
# names: charan
# names: nomesh
# names: bhavesh
# marks: 70.2
# marks: 80.3
# marks: 70.4

# %%
# string methods
name = "nomesh"
print(len(name))
print(name.startswith("nom"))
print(name.endswith("esh"))
print(name.capitalize())
# Out:
# 6
# True
# True
# Nomesh

# %%
# in lists we can store different types of data
items = ["Nani",85.2,6612,True]
print(items)
print(items[0])
# Out:
# ['Nani', 85.2, 6612, True]
# Nani

# %%
# list methods 1.sort
numbers = [20,30,20,15,10,2,5]
print((numbers.sort()))
for i in numbers:
  print(i)
# Out:
# None
# 2
# 5
# 10
# 15
# 20
# 20
# 30
