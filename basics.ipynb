# %% [markdown]
# <a href="https://colab.research.google.com/github/nomeshmudhiraj8-oss/chatbot/blob/main/basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Client Transformation
name = input("Enter Client Name:")
age  = int(input("Enter The CLient Age:"))
current_weight =int(input("Enter Current Weight:"))
goal_type = input("choose :(bulking,cutting)")
match(goal_type):
  case "bulking":
    goal_weight = (current_weight*1.5)
    print("after bulking:",goal_weight)
  case "cutting":
    current_weight = (current_weight+1.5)
    print("after cutting:",cutting)
# Out:
# Enter Client Name:Nomesh
# Enter The CLient Age:21
# Enter Current Weight:57
# choose :(bulking,cutting)bulking
# after bulking: 85.5
